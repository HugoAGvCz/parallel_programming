# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoAGvCz/parallel_programming/blob/main/insertion_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install mpi4py

# %%
! mpiexec --oversubscribe --allow-run-as-root -n 4 python /content/sample_data/insertion_sort.py
# Out:
# Arreglo original: [32, 88, -45, 31, 6, -6, -71, 46, -10, -100, 59, -12, -61, 69, 77, 97, -80, 24, 28, -46, 74, 68, -38, 62, 35, -91, 17, 49, 35, -59, 72, -19, -78, -77, -65, 52, -52, 27, 9, 17, 100, 42, -85, -80, 2, 9, 84, 96, 16, -22, -17, -23, 34, 74, -36, -3, 65, -7, -44, -26, 64, -73, -88, -65, -88, -61, 76, 92, 45, -87, 85, -60, 82, -30, 24, -90, -47, -14, -73, -36, -69, 22, 13, -83, -37, -92, -25, 77, 71, 48, -20, -63, -53, -75, 55, -28, -81, 97, 32, -35, 7, -37, 17, 33, 17, -66, 8, 16, -71, 89, 1, -6, -75, -33, 27, 22, -28, -14, -8, -24, -19, -79, 81, 1, 0, -68, -20, 86, -62, -42, 45, 99, -15, -47, -39, -68, -97, -49, -79, -44, -46, -22, -60, -72, 45, 36, -25, 46, 83, 72, 24, -85, -48, -45, -14, -4, -82, -41, 75, 42, 26, -6, 70, 5, 83, 18, -25, -62, 92, 30, 29, -17, -57, 55, 83, -91, -51, -54, 65, 100, -7, 13, 19, -93, 81, 1, -62, 79, -45, 5, -5, 96, -12, -3, -64, -16, -93, -56, -99, 13, -1, 67, 68, 98, -15, -32, -62, 54, -82, 51, -8, -80, 36, 62, 12, -60, 86, -81, 97, 65, -69
# ...

# %% [markdown]
# Número de procesos: 2, Tamaño del arreglo: 100
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Número de procesos: 4, Tamaño del arreglo: 100
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Número de procesos: 8, Tamaño del arreglo: 100
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Número de procesos: 16, Tamaño del arreglo: 100
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Número de procesos: 2, Tamaño del arreglo: 1000
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Número de procesos: 4, Tamaño del arreglo: 1000
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Número de procesos: 8, Tamaño del arreglo: 1000
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Número de procesos: 16, Tamaño del arreglo: 1000
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Número de procesos: 2, Tamaño del arreglo: 10000
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Número de procesos: 4, Tamaño del arreglo: 10000
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Número de procesos: 8, Tamaño del arreglo: 10000
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Número de procesos: 16, Tamaño del arreglo: 10000
# ![image.png](data:image/png;base64,...)
